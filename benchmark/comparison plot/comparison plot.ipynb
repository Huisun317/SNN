# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df02=pd.read_csv('02_cnnTest.csv')
df2=pd.read_csv('2_cnnTest.csv')
df4=pd.read_csv('4_cnnTest.csv')

# %%
df02_snn=pd.read_csv('02_snnTest.csv')
df2_snn=pd.read_csv('2_snnTest.csv')
df4_snn=pd.read_csv('4_snnTest.csv')

# %%
df_cnnTest=pd.DataFrame()

# %%
df_cnnTest['2e-2 Epsilon CNN']=df02['0']
df_cnnTest['2 Epsilon CNN']=df2['0']
df_cnnTest['4 Epsilon CNN']=df4['0']

df_cnnTest['2e-2 Epsilon SNN']=df02_snn['0']
df_cnnTest['2 Epsilon SNN']=df2_snn['0']
df_cnnTest['4 Epsilon SNN']=df4_snn['0']

# %%
df_cnnTest[['2e-2 Epsilon CNN', '2e-2 Epsilon SNN']].plot(figsize=(8,6), style=['-','-.'],color=['blue', 'red'])
plt.legend(['$\epsilon=0.2$ CNN','$\epsilon=0.2$ SNN'],fontsize=15)
plt.grid('-.')
plt.xlabel('Epochs')
plt.ylabel(' Test Accuracy ')
plt.title('Comparison between noisy CNN and SNN Test accuracy ')
plt.savefig('test02.png')

# %%
df_cnnTest[['2 Epsilon CNN', '2 Epsilon SNN']].plot(figsize=(8,6), style=['-','-.'],color=['blue', 'red'])
plt.legend(['$\epsilon=2.0$ CNN','$\epsilon=2.0$ SNN'],fontsize=15)
plt.grid('-.')
plt.xlabel('Epochs')
plt.ylabel(' Test Accuracy ')
plt.title('Comparison between noisy CNN and SNN Test accuracy ')
plt.savefig('test2.png')

# %%
df_cnnTest[['4 Epsilon CNN', '4 Epsilon SNN']].plot(figsize=(8,6), style=['-','-.'],color=['blue', 'red'])
plt.legend(['$\epsilon=4.0$ CNN','$\epsilon=4.0$ SNN'],fontsize=15)
plt.grid('-.')
plt.xlabel('Epochs')
plt.ylabel(' Test Accuracy ')
plt.title('Comparison between noisy CNN and SNN Test accuracy ')
plt.savefig('test4.png')

# %% [markdown]
# # Train result

# %%
df02=pd.read_csv('02_cnnTrain.csv')
df2=pd.read_csv('2_cnnTrain.csv')
df4=pd.read_csv('4_cnnTrain.csv')

# %%
df02_snn=pd.read_csv('02_snnTrain.csv')
df2_snn=pd.read_csv('2_snnTrain.csv')
df4_snn=pd.read_csv('4_snnTrain.csv')

# %%
df_cnnTrain=pd.DataFrame()

# %%
df_cnnTrain['2e-2 Epsilon CNN']=df02['0']
df_cnnTrain['2 Epsilon CNN']=df2['0']
df_cnnTrain['4 Epsilon CNN']=df4['0']

df_cnnTrain['2e-2 Epsilon SNN']=df02_snn['0']
df_cnnTrain['2 Epsilon SNN']=df2_snn['0']
df_cnnTrain['4 Epsilon SNN']=df4_snn['0']

# %%
df_cnnTrain[['2e-2 Epsilon CNN', '2e-2 Epsilon SNN']].plot(figsize=(8,6), style=['-','-.'],color=['blue', 'red'])
plt.legend(['$\epsilon=0.2$ CNN','$\epsilon=0.2$ SNN'],fontsize=15)
plt.grid('-.')
plt.xlabel('Epochs')
plt.ylabel(' Train Accuracy ')
plt.title('Comparison between noisy CNN and SNN Train accuracy ')
plt.savefig('train02.png')

# %%
df_cnnTrain[['2 Epsilon CNN', '2 Epsilon SNN']].plot(figsize=(8,6), style=['-','-.'],color=['blue', 'red'])
plt.legend(['$\epsilon=2.0$ CNN','$\epsilon=2.0$ SNN'],fontsize=15)
plt.grid('-.')
plt.xlabel('Epochs')
plt.ylabel(' Train Accuracy ')
plt.title('Comparison between noisy CNN and SNN Train accuracy ')
plt.savefig('train2.png')

# %%
df_cnnTrain[['4 Epsilon CNN', '4 Epsilon SNN']].plot(figsize=(8,6), style=['-','-.'],color=['blue', 'red'])
plt.legend(['$\epsilon=4.0$ CNN','$\epsilon=4.0$ SNN'],fontsize=15)
plt.grid('-.')
plt.xlabel('Epochs')
plt.ylabel(' Train Accuracy ')
plt.title('Comparison between noisy CNN and SNN Train accuracy ')
plt.savefig('train4.png')

# %% [markdown]
# # New comparison

# %%
import numpy as np

# %%
df00=pd.read_csv('00_cnnTest.csv')
df02=pd.read_csv('02_cnnTest.csv')
df1=pd.read_csv('1_cnnTest.csv')
df2=pd.read_csv('2_cnnTest.csv')
df4=pd.read_csv('4_cnnTest.csv')
df7=pd.read_csv('7_cnnTest.csv')
df10=pd.read_csv('10_cnnTest.csv')

df1_snn=pd.read_csv('1_snnTest.csv')

# %%
df_cnnTrain=pd.DataFrame()

# %%
#np.array([0.781,0.836,0.8608,0.8761,0.8804,0.8797,0.8892,0.892,0.893,0.892])

# %%
df_cnnTrain['1 SNN']=df1_snn['0']

df_cnnTrain['0.00 Epsilon CNN']=df00['0']
df_cnnTrain['0.02 Epsilon CNN']=df02['0']
df_cnnTrain['1 Epsilon CNN']=df1['0']
df_cnnTrain['2 Epsilon CNN']=df2['0']
df_cnnTrain['4 Epsilon CNN']=df4['0']
df_cnnTrain['7 Epsilon CNN']=df7['0']
df_cnnTrain['10 Epsilon CNN']=df10['0']

# %%
df_cnnTrain.plot(figsize=(10,6), style=['-o','--','--','--','--','--','--'])
plt.legend(['SNN','$\epsilon=0$ CNN','$\epsilon=0.2$ CNN', '$\epsilon=1.0$ CNN',
            '$\epsilon=2.0$ CNN','$\epsilon=4.0$ CNN','$\epsilon=7.0$ CNN','$\epsilon=10.0$ CNN'],fontsize=12)
plt.xlabel('Epochs')
plt.ylabel(' Test Accuracy ')
plt.grid('-.')
plt.title('Comparison between noisy CNN and SNN Test accuracy')
plt.savefig('comparison.png')

# %%
df_cnnTrain
# Out:
#     1 SNN  0.02 Epsilon CNN  1 Epsilon CNN  2 Epsilon CNN  4 Epsilon CNN  \
# 0  0.8137            0.7791         0.7420         0.6949         0.5170
# 1  0.8388            0.8166         0.7763         0.7359         0.6234
# 2  0.8525            0.8385         0.7945         0.7576         0.6618
# 3  0.8602            0.8590         0.8057         0.7688         0.6684
# 4  0.8627            0.8697         0.8029         0.7757         0.6703
# 5  0.8635            0.8743         0.8207         0.7700         0.6743
# 6  0.8677            0.8770         0.8301         0.7895         0.6872
# 7  0.8773            0.8892         0.8360         0.7902         0.6848
# 8  0.8754            0.8860         0.8324         0.7905         0.6773
# 9  0.8787            0.8898         0.8407         0.7988         0.6950
#
#    7 Epsilon CNN  10 Epsilon CNN  0.00 Epsilon CNN
# 0         0.0972          0.1058            0.7851
# 1         0.2320          0.0979            0.8260
# ...

# %%
df00=pd.read_csv('00_cnnTrain.csv')
df02=pd.read_csv('02_cnnTrain.csv')
df1=pd.read_csv('1_cnnTrain.csv')
df2=pd.read_csv('2_cnnTrain.csv')
df4=pd.read_csv('4_cnnTrain.csv')
df7=pd.read_csv('7_cnnTrain.csv')
df10=pd.read_csv('10_cnnTrain.csv')

df1_snn=pd.read_csv('1_snnTrain.csv')

# %%
df_cnnTrain=pd.DataFrame()

df_cnnTrain['1 SNN']=df1_snn['0']

df_cnnTrain['0 Epsilon CNN']=df00['0']
df_cnnTrain['0.02 Epsilon CNN']=df02['0']
df_cnnTrain['1 Epsilon CNN']=df1['0']
df_cnnTrain['2 Epsilon CNN']=df2['0']
df_cnnTrain['4 Epsilon CNN']=df4['0']
df_cnnTrain['7 Epsilon CNN']=df7['0']
df_cnnTrain['10 Epsilon CNN']=df10['0']

# %%
df_cnnTrain.plot(figsize=(10,6), style=['-o','--','--','--','--','--','--'])
plt.legend(['SNN','$\epsilon=0$ CNN','$\epsilon=0.2$ CNN', '$\epsilon=1.0$ CNN',
            '$\epsilon=2.0$ CNN','$\epsilon=4.0$ CNN','$\epsilon=7.0$ CNN','$\epsilon=10.0$ CNN'],fontsize=12)
plt.xlabel('Epochs')
plt.ylabel(' Train Accuracy ')
plt.grid('-.')
plt.title('Comparison between noisy CNN and SNN Train accuracy')
plt.savefig('comparison_train.png')

# %% [markdown]
# # Attacked data

# %%
df=pd.DataFrame()

# %%
df['Epsilon']=np.array([0.0, 0.2, 1.0, 2.0, 4.0, 7.0, 10.0])
df['0.0']=np.array([0.8891,0.8698, 0.8357, 0.7909, 0.6934, 0.5174, 0.2359])
df['0.05']=np.array([0.6174, 0.6318, 0.717, 0.6981, 0.632,0.4858, 0.2252])
df['0.10']=np.array([0.4415, 0.465,0.6061,0.6202,0.58,0.4318,0.2082])
df['0.15']=np.array([0.33,0.3649,0.5155,0.559,0.5281,0.373,0.1997])
df['0.2']=np.array([0.2512,0.3091,0.4399,0.512,0.46,0.329,0.1887])

# %%
df.set_index(['Epsilon'],inplace=True)
df=df.transpose()
df['SNN']=np.array([0.8835, 0.7701,0.666,0.584, 0.525])

# %%
df.plot(figsize=(10,8), style=['--','--','--','--','--','--','--','-o'])
plt.legend(['$\epsilon=0$ CNN','$\epsilon=0.2$ CNN', '$\epsilon=1.0$ CNN',
            '$\epsilon=2.0$ CNN','$\epsilon=4.0$ CNN','$\epsilon=7.0$ CNN','$\epsilon=10.0$ CNN','SNN'],fontsize=12)
plt.grid(linestyle='-.')
plt.xlabel('Alpha: level of FGSM Adversarial Attack on Test Data')
plt.ylabel('Test Accuracy on Attacked data')
plt.title('Comparison between noisy CNN and SNN on Attacked Test data accuracy')
plt.savefig('comparison_attack.png')
